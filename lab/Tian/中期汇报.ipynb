# %%
import pandas as pd

# %%
# 读取当前路径下的dataset.tsv
df = pd.read_csv('dataset.tsv', sep='\t')
df
# Out:
#    Series Accession  Samples
# 0         GSE213575        4  \
# 1         GSE213573        8
# 2         GSE213570       24
# 3         GSE221464       24
# 4         GSE214002        8
# 5         GSE214142       18
# 6         GSE205182       18
# 7         GSE184074       12
# 8         GSE183387       49
# 9         GSE114057       15
# 10        GSE111986        6
# 11        GSE165516       12
# 12        GSE110062        6
# 13        GSE137286       20
# 14         GSE57235        4
# 15         GSE27323       18
#
#                                                 Title
# 0   The putative methyltransferase LaeA regulates ...  \
# 1   The putative methyltransferase LaeA regulates ...
# 2   The putative methyltransferase LaeA regulates ...
# 3   The arabinose transporter MtLat-1 is involved ...
# 4   The Weimberg pathway: an alternative for Mycel...
# 5   PFK2/FBPase-2 is a potential target for metabo...
# 6   MtTRC-1, a Novel Transcription Factor, Regulat...
# ...

# %%
# 根据Insititute的单位，计算各单位的Samples列的值的总和
df.groupby('Institute')['Samples'].sum()
# Out:
# Institute
# Centre of fungal biodiversity                                                  20
# Concordia University                                                           22
# Technische Universität Berlin                                                  49
# Tianjin Institute of Industrial Biotechnology, Chinese Academy of Sciences     38
# Tianjin institute of industrial biotechnology,Chinses Academy of Sciences     117
# Name: Samples, dtype: int64

# %%
# 计算Samples列的值的总和
df['Samples'].sum()
# Out:
# 246
