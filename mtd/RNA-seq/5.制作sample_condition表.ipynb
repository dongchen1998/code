# %%
import pandas as pd

# %%
keyname = 'Nc'
path = '/Users/dongjiacheng/Desktop/coder/mtd/RNA-seq/'+ keyname +'/'
print(path)
# Out:
# /Users/dongjiacheng/Desktop/coder/mtd/RNA-seq/Nc/

# %% [markdown]
# 1. 生成sample_condition表

# %%
df = pd.read_csv(path + keyname + "_sample.tsv", sep="\t").copy()
df["Time"] = df["Time"].fillna("")
df["Condition"] = (
    df["Strain"]
    + " "
    + df["Strategy"].fillna("")
    + " "
    + df["Carbon Sources"].fillna("")
    + " "
    + df["Temperature"].fillna("")
    + " "
    + df["Time"].fillna("")
)

# df保留Sample Number、Sample ID、Series ID、Study Title、Species、Strain、Sample Name、Canbon Sources、Temperature列
df_1 = df[['Sample ID', 'Series Accession','Study Title', 'Condition', 'Related Sample']]

# 如果Conditon最后一位是_，则去掉
df_1.loc[:,'Condition'] = df_1['Condition'].apply(lambda x: x[:-1] if x[-1] == '_' else x)

df_1
# Out:
# /var/folders/9j/hx31vvg102g6r3rs7v7_4bw40000gn/T/ipykernel_50158/3729215933.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1.loc[:,'Condition'] = df_1['Condition'].apply(lambda x: x[:-1] if x[-1] == '_' else x)
#     Sample ID Series Accession  \
# 0    nc001001         GSE35227
# 1    nc001002         GSE35227
# 2    nc001003         GSE35227
# 3    nc001004         GSE35227
# 4    nc001005         GSE35227
# ..        ...              ...
# 444  nc063006        GSE222372
# 445  nc064001        GSE220169
# 446  nc064002        GSE220169
# 447  nc064003        GSE220169
# 448  nc064004        GSE220169
#
#                                            Study Title  \
# 0    Conserved and Essential Transcription Factors ...
# 1    Conserved and Essential Transcription Factors ...
# 2    Conserved and Essential Transcription Factors ...
# 3    Conserved and Essential Transcription Factors ...
# 4    Conserved and Essential Transcription Factors ...
# ..                                                 ...
# 444  The transcriptional factor Clr-5 is involved i...
# 445  The nutrient-sensing GCN2 signaling pathway is...
# 446  The nutrient-sensing GCN2 signaling pathway is...
# 447  The nutrient-sensing GCN2 signaling pathway is...
# 448  The nutrient-sensing GCN2 signaling pathway is...
#
#                                    Condition                    Related Sample
# 0                           cdr1  Avicel  1h                         GSM864216
# 1                           cdr1  Avicel  4h                         GSM864217
# 2                          cdr1  Sucrose  1h                         GSM864218
# 3                          cdr1  Sucrose  4h                         GSM864219
# 4                           cdr2  Avicel  1h                         GSM864220
# ..                                       ...                               ...
# 444                       WT_Leu  Avicel  8h             GSM6921756,GSM6921757
# 445       WT Constant light Glucose 25°C 18h  GSM6793047,GSM6793048,GSM6793049
# 446    cpc-1 Constant light Glucose 25°C 18h  GSM6793050,GSM6793051,GSM6793052
# 447     WT 12mm 3-aminotria Glucose 25°C 18h  GSM6793053,GSM6793054,GSM6793055
# 448  cpc-1 12mm 3-aminotria Glucose 25°C 18h  GSM6793056,GSM6793057,GSM6793058
#
# [449 rows x 5 columns]

# %%
# 读取dataset.tsv
df_2 = pd.read_csv(path + keyname + '_dataset.tsv', sep='\t').copy()
df_2 = df_2[['Series Accession', 'PMID']]

# 将df_2的PMID列转换为整数
df_2['PMID'] = df_2['PMID'].fillna(0).astype(int)

df_2
# Out:
#    Series Accession      PMID
# 0         GSE237909         0
# 1         GSE220169  37083494
# 2         GSE199259         0
# 3         GSE225621         0
# 4         GSE201901  36603054
# ..              ...       ...
# 91         GSE35227  22532664
# 92         GSE36719  22474347
# 93         GSE19824  20395474
# 94        GSE222372  38031036
# 95        GSE220169  37083494
#
# [96 rows x 2 columns]

# %% [markdown]
# 添加PMID

# %%
# 将df_1和df_2合并，根据Series ID列
df_3 = pd.merge(df_1, df_2, on='Series Accession', how='left')


# 将df_3的PMID列转换为整数
df_3['PMID'] = df_3['PMID'].fillna(0).astype(int)

# Sample ID不允许重复
df_3 = df_3.drop_duplicates(subset=['Sample ID'])

# 保存df_3为tsv文件
df_3.to_csv(path + keyname + '_sample_condition.tsv', sep='\t', index=False)

df_3
# Out:
#     Sample ID Series Accession  \
# 0    nc001001         GSE35227
# 1    nc001002         GSE35227
# 2    nc001003         GSE35227
# 3    nc001004         GSE35227
# 4    nc001005         GSE35227
# ..        ...              ...
# 444  nc063006        GSE222372
# 445  nc064001        GSE220169
# 447  nc064002        GSE220169
# 449  nc064003        GSE220169
# 451  nc064004        GSE220169
#
#                                            Study Title  \
# 0    Conserved and Essential Transcription Factors ...
# 1    Conserved and Essential Transcription Factors ...
# 2    Conserved and Essential Transcription Factors ...
# 3    Conserved and Essential Transcription Factors ...
# 4    Conserved and Essential Transcription Factors ...
# ..                                                 ...
# 444  The transcriptional factor Clr-5 is involved i...
# 445  The nutrient-sensing GCN2 signaling pathway is...
# 447  The nutrient-sensing GCN2 signaling pathway is...
# 449  The nutrient-sensing GCN2 signaling pathway is...
# 451  The nutrient-sensing GCN2 signaling pathway is...
#
#                                    Condition  \
# 0                           cdr1  Avicel  1h
# 1                           cdr1  Avicel  4h
# 2                          cdr1  Sucrose  1h
# 3                          cdr1  Sucrose  4h
# 4                           cdr2  Avicel  1h
# ..                                       ...
# 444                       WT_Leu  Avicel  8h
# 445       WT Constant light Glucose 25°C 18h
# 447    cpc-1 Constant light Glucose 25°C 18h
# 449     WT 12mm 3-aminotria Glucose 25°C 18h
# 451  cpc-1 12mm 3-aminotria Glucose 25°C 18h
#
#                        Related Sample      PMID
# 0                           GSM864216  22532664
# 1                           GSM864217  22532664
# 2                           GSM864218  22532664
# 3                           GSM864219  22532664
# 4                           GSM864220  22532664
# ..                                ...       ...
# 444             GSM6921756,GSM6921757  38031036
# 445  GSM6793047,GSM6793048,GSM6793049  37083494
# 447  GSM6793050,GSM6793051,GSM6793052  37083494
# 449  GSM6793053,GSM6793054,GSM6793055  37083494
# 451  GSM6793056,GSM6793057,GSM6793058  37083494
#
# [449 rows x 6 columns]
