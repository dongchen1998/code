# %%
import pandas as pd

# %%
keyname = 'Mt'
path = '/Users/dongjiacheng/Desktop/coder/mtd/RNA-seq/'+ keyname +'/'
print(path)
# Out:
# /Users/dongjiacheng/Desktop/coder/mtd/RNA-seq/Mt/

# %% [markdown]
# 1. 标准化

# %%
df_sample = pd.read_excel(path + keyname + "_sample_raw_2023.12.28.xlsx").copy()

df_sample['Strategy'] = df_sample['Strategy'].fillna('')
df_sample['Carbon Sources'] = df_sample['Carbon Sources'].fillna('')
df_sample['Temperature'] = df_sample['Temperature'].fillna('')
df_sample['Time'] = df_sample['Time'].fillna('')

# Strain列转为str类型
df_sample['Strain'] = df_sample['Strain'].astype(str) 

df_sample['Carbon Sources'] = df_sample['Carbon Sources'].apply(lambda x: x.strip())
df_sample['Strain'] = df_sample['Strain'].apply(lambda x: x.strip())

df_sample['Strategy'] = df_sample['Strategy'].apply(lambda x: x.capitalize())
df_sample['Carbon Sources'] = df_sample['Carbon Sources'].apply(lambda x: x.capitalize())

df_sample
# Out:
#     Sample ID Sample Name   Experiment          Run Series Accession  \
# 0    mt001001   GSM675519    SRX043463    SRR101401         GSE27323
# 1    mt001002   GSM675520    SRX043464    SRR101402         GSE27323
# 2    mt001004   GSM675521    SRX043465    SRR101403         GSE27323
# 3    mt001005   GSM675522    SRX043466    SRR101404         GSE27323
# 4    mt001002   GSM675523    SRX043467    SRR101405         GSE27323
# ..        ...         ...          ...          ...              ...
# 228  mt015003  GSM7104566  SRX19719222  SRR23907599        GSE227646
# 229  mt015003  GSM7104567  SRX19719223  SRR23907598        GSE227646
# 230  mt015004  GSM7104568  SRX19719224  SRR23907597        GSE227646
# 231  mt015004  GSM7104569  SRX19719225  SRR23907596        GSE227646
# 232  mt015004  GSM7104570  SRX19719226  SRR23907595        GSE227646
#
#                                            Study Title  \
# 0    Transcriptomic response to substrate and tempe...
# 1    Transcriptomic response to substrate and tempe...
# 2    Transcriptomic response to substrate and tempe...
# 3    Transcriptomic response to substrate and tempe...
# 4    Transcriptomic response to substrate and tempe...
# ..                                                 ...
# 228  Development of a glucoamylase hyper-production...
# 229  Development of a glucoamylase hyper-production...
# 230  Development of a glucoamylase hyper-production...
# 231  Development of a glucoamylase hyper-production...
# 232  Development of a glucoamylase hyper-production...
#
#                                       Species                        Model  \
# 0               Thermothelomyces thermophilus  Illumina Genome Analyzer II
# 1               Thermothelomyces thermophilus  Illumina Genome Analyzer II
# 2               Thermothelomyces thermophilus  Illumina Genome Analyzer II
# 3               Thermothelomyces thermophilus  Illumina Genome Analyzer II
# 4               Thermothelomyces thermophilus  Illumina Genome Analyzer II
# ..                                        ...                          ...
# 228  Thermothelomyces thermophilus ATCC 42464          Illumina HiSeq 2000
# 229  Thermothelomyces thermophilus ATCC 42464          Illumina HiSeq 2000
# 230  Thermothelomyces thermophilus ATCC 42464          Illumina HiSeq 2000
# 231  Thermothelomyces thermophilus ATCC 42464          Illumina HiSeq 2000
# 232  Thermothelomyces thermophilus ATCC 42464          Illumina HiSeq 2000
#
#     Library Seletion  Library Source Library Strategy  \
# 0               cDNA  transcriptomic          RNA-Seq
# 1               cDNA  transcriptomic          RNA-Seq
# 2               cDNA  transcriptomic          RNA-Seq
# 3               cDNA  transcriptomic          RNA-Seq
# 4               cDNA  transcriptomic          RNA-Seq
# ..               ...             ...              ...
# 228             cDNA  transcriptomic          RNA-Seq
# 229             cDNA  transcriptomic          RNA-Seq
# 230             cDNA  transcriptomic          RNA-Seq
# 231             cDNA  transcriptomic          RNA-Seq
# 232             cDNA  transcriptomic          RNA-Seq
#
#                                          Samples Strain Strategy  \
# 0     Myceliophthora_thermophila_Barley_34C_rep1     WT
# 1     Myceliophthora_thermophila_Barley_45C_rep1     WT
# 2    Myceliophthora_thermophila_Glucose_45C_rep1     WT
# 3    Myceliophthora_thermophila_Alfalfa_45C_rep1     WT
# 4     Myceliophthora_thermophila_Barley_45C_rep2     WT
# ..                                           ...    ...      ...
# 228                                     WT_S1d_2     WT
# 229                                     WT_S1d_3     WT
# 230                                     WT_S2d_1     WT
# 231                                     WT_S2d_2     WT
# 232                                     WT_S2d_3     WT
#
#     Carbon Sources Temperature Time      Year
# 0           Barley         34°       2011 Oct
# 1           Barley         45°       2011 Oct
# 2          Glucose         45°       2011 Oct
# 3          Alfalfa         45°       2011 Oct
# 4           Barley         45°       2011 Oct
# ..             ...         ...  ...       ...
# 228         Starch         45°   1d  2023 Mar
# 229         Starch         45°   1d  2023 Mar
# 230         Starch         45°   2d  2023 Mar
# 231         Starch         45°   2d  2023 Mar
# 232         Starch         45°   2d  2023 Mar
#
# [233 rows x 18 columns]

# %% [markdown]
# 聚合
# 1. 一个fname号对应一个或者多个样本
# 2. 聚合后，则方便后续查看平均值

# %%
df_sample_change = df_sample.groupby('Sample ID').agg({
    'Sample Name':lambda x: ','.join(x),
    'Experiment':lambda x: ','.join(x),
    'Run':lambda x: ','.join(x),
    'Series Accession':lambda x: ','.join(x),
    'Study Title':lambda x: ';'.join(x),
    'Species':lambda x: ','.join(x),
    'Model':lambda x: ','.join(x),
    'Library Seletion':lambda x: ','.join(x),
    'Library Source':lambda x: ','.join(x),
    'Library Strategy':lambda x: ','.join(x),
    'Samples':lambda x: ','.join(x),
    'Strain':lambda x: ','.join(str(i) for i in x),
    'Strategy':lambda x: ','.join(str(i) for i in x),
    'Carbon Sources':lambda x: ','.join(str(i) for i in x),
    'Temperature':lambda x: ','.join(str(i) for i in x),
    'Time':lambda x: ','.join(str(i) for i in x),
    'Year':lambda x: ','.join(str(i) for i in x),
    }).reset_index()

df_sample_change
# Out:
#     Sample ID                       Sample Name  \
# 0    mt001001                         GSM675519
# 1    mt001002               GSM675520,GSM675523
# 2    mt001003               GSM675524,GSM675525
# 3    mt001004                         GSM675521
# 4    mt001005                         GSM675522
# ..        ...                               ...
# 107  mt014012             GSM6873698,GSM6873699
# 108  mt015001  GSM7104559,GSM7104560,GSM7104561
# 109  mt015002  GSM7104562,GSM7104563,GSM7104564
# 110  mt015003  GSM7104565,GSM7104566,GSM7104567
# 111  mt015004  GSM7104568,GSM7104569,GSM7104570
#
#                               Experiment                                  Run  \
# 0                              SRX043463                            SRR101401
# 1                   SRX043464, SRX043467                  SRR101402,SRR101405
# 2                   SRX043468, SRX043469                  SRR101406,SRR101407
# 3                              SRX043465                            SRR101403
# 4                              SRX043466                            SRR101404
# ..                                   ...                                  ...
# 107             SRX18797671, SRX18797672              SRR22838469,SRR22838468
# 108  SRX19719215,SRX19719216,SRX19719217  SRR23907606,SRR23907605,SRR23907604
# 109  SRX19719218,SRX19719219,SRX19719220  SRR23907603,SRR23907602,SRR23907601
# 110  SRX19719221,SRX19719222,SRX19719223  SRR23907600,SRR23907599,SRR23907598
# 111  SRX19719224,SRX19719225,SRX19719226  SRR23907597,SRR23907596,SRR23907595
#
#                   Series Accession  \
# 0                         GSE27323
# 1                GSE27323,GSE27323
# 2                GSE27323,GSE27323
# 3                         GSE27323
# 4                         GSE27323
# ..                             ...
# 107            GSE221464,GSE221464
# 108  GSE227646,GSE227646,GSE227646
# 109  GSE227646,GSE227646,GSE227646
# 110  GSE227646,GSE227646,GSE227646
# 111  GSE227646,GSE227646,GSE227646
#
#                                            Study Title  \
# 0    Transcriptomic response to substrate and tempe...
# 1    Transcriptomic response to substrate and tempe...
# 2    Transcriptomic response to substrate and tempe...
# 3    Transcriptomic response to substrate and tempe...
# 4    Transcriptomic response to substrate and tempe...
# ..                                                 ...
# 107  The arabinose transporter MtLat-1 is involved ...
# 108  Development of a glucoamylase hyper-production...
# 109  Development of a glucoamylase hyper-production...
# 110  Development of a glucoamylase hyper-production...
# 111  Development of a glucoamylase hyper-production...
#
#                                                Species  \
# 0                        Thermothelomyces thermophilus
# 1    Thermothelomyces thermophilus,Thermothelomyces...
# 2    Thermothelomyces thermophilus,Thermothelomyces...
# 3                        Thermothelomyces thermophilus
# 4                        Thermothelomyces thermophilus
# ..                                                 ...
# 107  Thermothelomyces thermophilus ATCC 42464,Therm...
# 108  Thermothelomyces thermophilus ATCC 42464,Therm...
# 109  Thermothelomyces thermophilus ATCC 42464,Therm...
# 110  Thermothelomyces thermophilus ATCC 42464,Therm...
# 111  Thermothelomyces thermophilus ATCC 42464,Therm...
#
#                                                  Model Library Seletion  \
# 0                          Illumina Genome Analyzer II             cDNA
# 1    Illumina Genome Analyzer II,Illumina Genome An...        cDNA,cDNA
# 2    Illumina Genome Analyzer II,Illumina Genome An...        cDNA,cDNA
# 3                          Illumina Genome Analyzer II             cDNA
# 4                          Illumina Genome Analyzer II             cDNA
# ..                                                 ...              ...
# 107            Illumina HiSeq 2000,Illumina HiSeq 2000        cDNA,cDNA
# 108  Illumina HiSeq 2000,Illumina HiSeq 2000,Illumi...   cDNA,cDNA,cDNA
# 109  Illumina HiSeq 2000,Illumina HiSeq 2000,Illumi...   cDNA,cDNA,cDNA
# 110  Illumina HiSeq 2000,Illumina HiSeq 2000,Illumi...   cDNA,cDNA,cDNA
# 111  Illumina HiSeq 2000,Illumina HiSeq 2000,Illumi...   cDNA,cDNA,cDNA
#
#                                    Library Source         Library Strategy  \
# 0                                  transcriptomic                  RNA-Seq
# 1                   transcriptomic,transcriptomic          RNA-Seq,RNA-Seq
# 2                   transcriptomic,transcriptomic          RNA-Seq,RNA-Seq
# 3                                  transcriptomic                  RNA-Seq
# 4                                  transcriptomic                  RNA-Seq
# ..                                            ...                      ...
# 107                 transcriptomic,transcriptomic          RNA-Seq,RNA-Seq
# 108  transcriptomic,transcriptomic,transcriptomic  RNA-Seq,RNA-Seq,RNA-Seq
# 109  transcriptomic,transcriptomic,transcriptomic  RNA-Seq,RNA-Seq,RNA-Seq
# 110  transcriptomic,transcriptomic,transcriptomic  RNA-Seq,RNA-Seq,RNA-Seq
# 111  transcriptomic,transcriptomic,transcriptomic  RNA-Seq,RNA-Seq,RNA-Seq
#
#                                                Samples                Strain  \
# 0           Myceliophthora_thermophila_Barley_34C_rep1                    WT
# 1    Myceliophthora_thermophila_Barley_45C_rep1,Myc...                 WT,WT
# 2    Myceliophthora_thermophila_Glucose_34C_rep1,My...                 WT,WT
# 3          Myceliophthora_thermophila_Glucose_45C_rep1                    WT
# 4          Myceliophthora_thermophila_Alfalfa_45C_rep1                    WT
# ..                                                 ...                   ...
# 107                  WT_arabinan_4h_1,WT_arabinan_4h_2                 WT,WT
# 108             MtGM12_S1d_1,MtGM12_S1d_2,MtGM12_S1d_3  MtGM12,MtGM12,MtGM12
# 109             MtGM12_S2d_1,MtGM12_S2d_2,MtGM12_S2d_3  MtGM12,MtGM12,MtGM12
# 110                         WT_S1d_1,WT_S1d_2,WT_S1d_3              WT,WT,WT
# 111                         WT_S2d_1,WT_S2d_2,WT_S2d_3              WT,WT,WT
#
#     Strategy        Carbon Sources  Temperature      Time  \
# 0                           Barley          34°
# 1          ,         Barley,Barley      45°,45°         ,
# 2          ,       Glucose,Glucose      34°,45°         ,
# 3                          Glucose          45°
# 4                          Alfalfa          45°
# ..       ...                   ...          ...       ...
# 107        ,     Arabinan,Arabinan      45°,45°     4h,4h
# 108       ,,  Starch,Starch,Starch  45°,45°,45°  1d,1d,1d
# 109       ,,  Starch,Starch,Starch  45°,45°,45°  2d,2d,2d
# 110       ,,  Starch,Starch,Starch  45°,45°,45°  1d,1d,1d
# 111       ,,  Starch,Starch,Starch  45°,45°,45°  2d,2d,2d
#
#                            Year
# 0                      2011 Oct
# 1             2011 Oct,2011 Oct
# 2             2011 Oct,2011 Oct
# 3                      2011 Oct
# 4                      2011 Oct
# ..                          ...
# 107           2023 Mar,2023 Mar
# 108  2023 Mar,2023 Mar,2023 Mar
# 109  2023 Mar,2023 Mar,2023 Mar
# 110  2023 Mar,2023 Mar,2023 Mar
# 111  2023 Mar,2023 Mar,2023 Mar
#
# [112 rows x 18 columns]

# %%
"""
Series ID这一列中，存在多个值，如果值相同则值合并
"""
df_sample_change['Series Accession'] = df_sample_change['Series Accession'].str.split(',').str[0]
df_sample_change['Study Title'] = df_sample_change['Study Title'].str.split(';').str[0]
df_sample_change['Species'] = df_sample_change['Species'].str.split(',').str[0]
df_sample_change['Strain'] = df_sample_change['Strain'].str.split(',').str[0]
df_sample_change['Model'] = df_sample_change['Model'].str.split(',').str[0]
df_sample_change['Library Seletion'] = df_sample_change['Library Seletion'].str.split(',').str[0]
df_sample_change['Library Source'] = df_sample_change['Library Source'].str.split(',').str[0]
df_sample_change['Library Strategy'] = df_sample_change['Library Strategy'].str.split(',').str[0]
df_sample_change['Strain'] = df_sample_change['Strain'].str.split(',').str[0]
df_sample_change['Strategy'] = df_sample_change['Strategy'].str.split(',').str[0]
df_sample_change['Carbon Sources'] = df_sample_change['Carbon Sources'].str.split(',').str[0]
df_sample_change['Temperature'] = df_sample_change['Temperature'].str.split(',').str[0]
df_sample_change['Time'] = df_sample_change['Time'].str.split(',').str[0]
df_sample_change['Year'] = df_sample_change['Year'].str.split(',').str[0]

df_sample_change.head()
# Out:
#   Sample ID          Sample Name             Experiment                  Run  \
# 0  mt001001            GSM675519              SRX043463            SRR101401
# 1  mt001002  GSM675520,GSM675523   SRX043464, SRX043467  SRR101402,SRR101405
# 2  mt001003  GSM675524,GSM675525   SRX043468, SRX043469  SRR101406,SRR101407
# 3  mt001004            GSM675521              SRX043465            SRR101403
# 4  mt001005            GSM675522              SRX043466            SRR101404
#
#   Series Accession                                        Study Title  \
# 0         GSE27323  Transcriptomic response to substrate and tempe...
# 1         GSE27323  Transcriptomic response to substrate and tempe...
# 2         GSE27323  Transcriptomic response to substrate and tempe...
# 3         GSE27323  Transcriptomic response to substrate and tempe...
# 4         GSE27323  Transcriptomic response to substrate and tempe...
#
#                          Species                        Model  \
# 0  Thermothelomyces thermophilus  Illumina Genome Analyzer II
# 1  Thermothelomyces thermophilus  Illumina Genome Analyzer II
# 2  Thermothelomyces thermophilus  Illumina Genome Analyzer II
# 3  Thermothelomyces thermophilus  Illumina Genome Analyzer II
# 4  Thermothelomyces thermophilus  Illumina Genome Analyzer II
#
#   Library Seletion  Library Source Library Strategy  \
# 0             cDNA  transcriptomic          RNA-Seq
# 1             cDNA  transcriptomic          RNA-Seq
# 2             cDNA  transcriptomic          RNA-Seq
# 3             cDNA  transcriptomic          RNA-Seq
# 4             cDNA  transcriptomic          RNA-Seq
#
#                                              Samples Strain Strategy  \
# 0         Myceliophthora_thermophila_Barley_34C_rep1     WT
# 1  Myceliophthora_thermophila_Barley_45C_rep1,Myc...     WT
# 2  Myceliophthora_thermophila_Glucose_34C_rep1,My...     WT
# 3        Myceliophthora_thermophila_Glucose_45C_rep1     WT
# 4        Myceliophthora_thermophila_Alfalfa_45C_rep1     WT
#
#   Carbon Sources Temperature Time      Year
# 0         Barley         34°       2011 Oct
# 1         Barley         45°       2011 Oct
# 2        Glucose         34°       2011 Oct
# 3        Glucose         45°       2011 Oct
# 4        Alfalfa         45°       2011 Oct

# %%
"""
筛选目标列
"""
df_sample_filter = df_sample_change[['Sample ID', 'Strain', 'Strategy' ,'Carbon Sources', 'Temperature', 'Time', 'Study Title', 'Series Accession', 'Sample Name']].copy()

df_sample_filter.rename(columns={'Sample Name':'Related Sample'}, inplace=True)

df_sample_filter
# Out:
#     Sample ID  Strain Strategy Carbon Sources Temperature Time  \
# 0    mt001001      WT                  Barley         34°
# 1    mt001002      WT                  Barley         45°
# 2    mt001003      WT                 Glucose         34°
# 3    mt001004      WT                 Glucose         45°
# 4    mt001005      WT                 Alfalfa         45°
# ..        ...     ...      ...            ...         ...  ...
# 107  mt014012      WT                Arabinan         45°   4h
# 108  mt015001  MtGM12                  Starch         45°   1d
# 109  mt015002  MtGM12                  Starch         45°   2d
# 110  mt015003      WT                  Starch         45°   1d
# 111  mt015004      WT                  Starch         45°   2d
#
#                                            Study Title Series Accession  \
# 0    Transcriptomic response to substrate and tempe...         GSE27323
# 1    Transcriptomic response to substrate and tempe...         GSE27323
# 2    Transcriptomic response to substrate and tempe...         GSE27323
# 3    Transcriptomic response to substrate and tempe...         GSE27323
# 4    Transcriptomic response to substrate and tempe...         GSE27323
# ..                                                 ...              ...
# 107  The arabinose transporter MtLat-1 is involved ...        GSE221464
# 108  Development of a glucoamylase hyper-production...        GSE227646
# 109  Development of a glucoamylase hyper-production...        GSE227646
# 110  Development of a glucoamylase hyper-production...        GSE227646
# 111  Development of a glucoamylase hyper-production...        GSE227646
#
#                        Related Sample
# 0                           GSM675519
# 1                 GSM675520,GSM675523
# 2                 GSM675524,GSM675525
# 3                           GSM675521
# 4                           GSM675522
# ..                                ...
# 107             GSM6873698,GSM6873699
# 108  GSM7104559,GSM7104560,GSM7104561
# 109  GSM7104562,GSM7104563,GSM7104564
# 110  GSM7104565,GSM7104566,GSM7104567
# 111  GSM7104568,GSM7104569,GSM7104570
#
# [112 rows x 9 columns]

# %%
df_sample_filter.to_csv(path + keyname + '_sample.tsv', sep='\t', index=False)
