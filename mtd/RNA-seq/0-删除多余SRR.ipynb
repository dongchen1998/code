# %%
import pandas as pd
import os

path = './Nc/'
keyname = 'Nc'
df = pd.read_excel(path + keyname + '_sample_srr.xlsx').copy()
df
# Out:
#     Sample ID Sample Name   Experiment          Run Series Accession
# 0    nc001001   GSM864216    SRX116656    SRR400635         GSE35227  \
# 1    nc001002   GSM864217    SRX116657    SRR400636         GSE35227
# 2    nc001003   GSM864218    SRX116658    SRR400637         GSE35227
# 3    nc001004   GSM864219    SRX116659    SRR400638         GSE35227
# 4    nc001005   GSM864220    SRX116660    SRR400639         GSE35227
# ..        ...         ...          ...          ...              ...
# 846  nc062008  GSM5460930  SRX11493476  SRR15186060        GSE180332
# 847  nc062009  GSM6077761  SRX15048742  SRR18972872        GSE201901
# 848  nc062010  GSM6077762  SRX15048743  SRR18972871        GSE201901
# 849  nc062009  GSM6077763  SRX15048744  SRR18972870        GSE201901
# 850  nc062010  GSM6077764  SRX15048745  SRR18972869        GSE201901
#
#                                            Study Title
# 0    Conserved and Essential Transcription Factors ...  \
# ...

# %%
# 如果Run列中有多个SRR，只保留第一个
df['Run'] = df['Run'].apply(lambda x: x.split(',')[0])
df
# Out:
#     Sample ID Sample Name   Experiment          Run Series Accession
# 0    nc001001   GSM864216    SRX116656    SRR400635         GSE35227  \
# 1    nc001002   GSM864217    SRX116657    SRR400636         GSE35227
# 2    nc001003   GSM864218    SRX116658    SRR400637         GSE35227
# 3    nc001004   GSM864219    SRX116659    SRR400638         GSE35227
# 4    nc001005   GSM864220    SRX116660    SRR400639         GSE35227
# ..        ...         ...          ...          ...              ...
# 846  nc062008  GSM5460930  SRX11493476  SRR15186060        GSE180332
# 847  nc062009  GSM6077761  SRX15048742  SRR18972872        GSE201901
# 848  nc062010  GSM6077762  SRX15048743  SRR18972871        GSE201901
# 849  nc062009  GSM6077763  SRX15048744  SRR18972870        GSE201901
# 850  nc062010  GSM6077764  SRX15048745  SRR18972869        GSE201901
#
#                                            Study Title
# 0    Conserved and Essential Transcription Factors ...  \
# ...

# %%
df.to_excel(path + keyname'_sample_raw.xlsx', index=False)
