# %%
import pandas as pd

# %%
keyname = 'Nc'
path = '/Users/dongjiacheng/Desktop/coder/mtd/RNA-seq/'+ keyname +'/'
print(path)
# Out:
# /Users/dongjiacheng/Desktop/coder/mtd/RNA-seq/Nc/

# %%
exp_df = pd.read_csv(path + keyname + '_exp.tsv', sep='\t').copy()
sample_df = pd.read_csv(path + keyname + '_sample.tsv', sep='\t').copy()

# 将Temperature空值设置为''
sample_df['Temperature'] = sample_df['Temperature'].fillna('')
sample_df['Carbon Sources'] = sample_df['Carbon Sources'].fillna('')
sample_df['Time'] = sample_df['Time'].fillna('')

# 将Sample ID、Strain、Carbon Sources、Temperature、Time的值组合成新的列名
sample_df['New_Column_Name'] = sample_df['Sample ID'] + ' ' + sample_df['Strain'] + ' ' + sample_df['Carbon Sources'] + ' ' + sample_df['Temperature'] + ' ' + sample_df['Time'].astype(str)

# 创建一个映射字典
rename_dict = sample_df.set_index('Sample ID')['New_Column_Name'].to_dict()

# 使用字典重命名exp.tsv的列名
exp_df.rename(columns=rename_dict, inplace=True)

# 查看更改后的exp.tsv
exp_df
# Out:
#         Gene id  nc043001 delta_lsd1 Sucrose 32° 16h  nc006001 OR74A   6h  \
# 0      NCU10129                                20.99                 0.47
# 1      NCU09901                                 8.49                15.15
# 2      NCU09903                                 1.44                42.54
# 3      NCU11134                                 0.00                 0.00
# 4      NCU09904                                11.32                 0.34
# ...         ...                                  ...                  ...
# 10585  NCU16025                                 5.00                 4.10
# 10586  NCU16026                                 0.00                 0.00
# 10587  NCU16027                                48.50                 7.17
# 10588  NCU16028                                54.74                 6.82
# 10589  NCU16228                                38.82                21.09
#
#        nc006002 OR74A   6h  nc006003 Δczt-1   6h  nc006004 Δczt-1   6h  \
# 0                     3.91                  1.01                  4.44
# 1                    10.93                  8.67                  3.92
# 2                     9.87                 24.69                  2.44
# 3                     0.23                  0.22                  0.76
# 4                     0.99                  0.29                  2.18
# ...                    ...                   ...                   ...
# 10585                 3.55                  8.80                  5.46
# 10586                 0.00                  0.00                  0.00
# 10587                33.34                 58.67                 50.77
# 10588                33.61                 64.74                 61.05
# 10589                15.81                 21.79                 21.28
#
#        nc010001 FGSC 11308: Δvib-1 a No carbon    \
# 0                                          15.73
# 1                                           5.11
# 2                                           4.12
# 3                                           0.22
# 4                                           1.15
# ...                                          ...
# 10585                                       1.69
# 10586                                       0.00
# 10587                                      19.51
# 10588                                      24.44
# 10589                                       7.09
#
#        nc010002 FGSC 11308 Δvib-1 a Avicel    \
# 0                                      11.37
# 1                                       5.73
# 2                                       3.97
# 3                                       0.33
# 4                                       2.34
# ...                                      ...
# 10585                                   0.76
# 10586                                   0.00
# 10587                                   9.97
# 10588                                  15.65
# 10589                                  10.78
#
#        nc010003 YX025: Pc clr-2 Δvib-1 a No carbon    nc013002 OR74A     ...  \
# 0                                              10.83               0.47  ...
# 1                                               4.29              15.15  ...
# 2                                               1.74              42.53  ...
# 3                                               0.14               0.00  ...
# 4                                               0.47               0.34  ...
# ...                                              ...                ...  ...
# 10585                                           2.64               4.10  ...
# 10586                                           0.00               0.00  ...
# 10587                                          27.67               7.17  ...
# 10588                                          33.63               6.81  ...
# 10589                                          12.47              21.08  ...
#
#        nc048004 301-6 Glucose    nc041001 delta-mus52 Sucrose  5d  \
# 0                          7.40                              2.87
# 1                          7.05                              9.71
# 2                          7.89                             51.83
# 3                          1.16                              0.91
# 4                          0.90                              0.75
# ...                         ...                               ...
# 10585                      1.38                              0.17
# 10586                      0.00                              0.00
# 10587                      4.04                              0.87
# 10588                      9.93                              0.82
# 10589                      0.22                              0.00
#
#        nc041002 delta-mus52 Sucrose  5d  nc041003 delta-pac3 Sucrose  10d  \
# 0                                  2.72                              8.09
# 1                                  9.51                             10.42
# 2                                 27.15                             54.60
# 3                                  0.51                              0.37
# 4                                  0.47                              0.90
# ...                                 ...                               ...
# 10585                              0.41                              0.19
# 10586                              0.00                              0.00
# 10587                              2.36                              1.11
# 10588                              2.21                              2.10
# 10589                              0.12                              0.00
#
#        nc041004 delta-pac3 Sucrose  10d  nc004001 OR74A   5h  \
# 0                                  6.18                 2.28
# 1                                  9.98                10.97
# 2                                 53.97                26.35
# 3                                  0.42                 0.34
# 4                                  0.84                 0.34
# ...                                 ...                  ...
# 10585                              0.32                 1.99
# 10586                              0.00                 0.00
# 10587                              2.00                33.38
# 10588                              2.99                30.90
# 10589                              0.00                20.24
#
#        nc004002 Δpp   5h  nc011001 OR74A Aarabinose    \
# 0                  36.58                         6.84
# 1                  30.22                        12.18
# 2                  35.37                        15.82
# 3                  20.66                         0.16
# 4                  12.31                        19.45
# ...                  ...                          ...
# 10585             237.59                         4.28
# 10586               0.00                         0.00
# 10587            1184.66                        50.08
# 10588             757.43                        59.58
# 10589            1570.55                        17.73
#
#        nc011002 OR74A Glucose    nc011003 OR74A Xylose
# 0                          2.89                     3.10
# 1                         10.29                    10.59
# 2                         21.04                    26.72
# 3                          0.10                     0.26
# 4                          5.74                     1.05
# ...                         ...                      ...
# 10585                      3.56                     4.81
# 10586                      0.00                     0.00
# 10587                     40.26                    79.21
# 10588                     35.55                    75.57
# 10589                     11.80                    13.81
#
# [10590 rows x 450 columns]

# %%
# 保存exp_df为tsv
exp_df.to_csv(path + keyname + '_exp_condition.tsv', sep='\t', index=False)
