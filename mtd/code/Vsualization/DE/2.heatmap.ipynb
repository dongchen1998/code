# %%
import numpy as np
import pandas as pd
import plotly.express as px

# 加载数据
df_demo_RPKM = pd.read_csv("demo-RPKM.csv")
df_demo_RPKM2 = pd.read_csv("./Mt_exp_autohagy.csv")

def heatmap(df, corlor_scale, button):

    # df第一列改名为gene_id
    df = df.rename(columns={df.columns[0]: 'gene_id'})
    # 提取gene_id作为索引
    df = df.set_index('gene_id')

    if button == 'Z-score':
        # 将数据进行归一化，范围-2到2
        df_normalized = df.apply(lambda x: np.interp(x, (x.min(), x.max()), (-2, 2)))
    
    # 如果button==log2，那么进行log2变换
    elif button == 'log2':
        df_normalized = np.log(df+1)
    else:
        df_normalized = df

    # 将归一化后的DataFrame转置，使样本名称在x轴，基因id在y轴
    df_normalized = df_normalized.transpose()

    # 创建热图
    fig = px.imshow(df_normalized,
                    labels=dict(x="Sample", y="Gene ID", color="RPKM"),
                    x=df_normalized.columns,
                    y=df_normalized.index,
                    color_continuous_scale=corlor_scale
                   )

    # 定义鼠标悬浮数据显示方式
    fig.update_traces(hovertemplate='Gene: %{x}<br>Sample: %{y}<br>RPKM: %{z:.1f}')
    fig.update_layout(title='Gene expression heatmap')

    return fig

# 读取文件
df_demo_RPKM = pd.read_csv("demo-RPKM.csv")

# 调用函数
heatmap(df_demo_RPKM, 'curl', 'Z-score')

# %%
heatmap(df_demo_RPKM2, 'Aggrnyl', 'log2')

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

def create_heatmap(df):
    # df第一列改名为gene_id
    df = df.rename(columns={df.columns[0]: 'gene_id'})
    # 提取gene_id作为索引
    df = df.set_index('gene_id')
    # 将数据进行归一化，范围-2到2
    df_normalized = df.apply(lambda x: np.interp(x, (x.min(), x.max()), (-2, 2)))
    # 创建热图
    fig = go.Figure(data=go.Heatmap(
        z=df_normalized,
        x=df_normalized.columns,
        y=df_normalized.index,
        colorscale='RdBu_r',
        hovertemplate='Sample: %{x}<br>Gene ID: %{y}<br>FPKM: %{z:.3f}<extra></extra>'
    ))
    # 设置轴标签
    fig.update_layout(
        xaxis_title="Sample",
        yaxis_title="Gene ID"
    )
    return fig

create_heatmap(df_demo_fpkm)

# %%
create_heatmap(df_demo_fpkm2)
