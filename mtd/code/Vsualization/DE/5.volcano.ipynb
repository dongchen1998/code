# %%
# 读取excel文件
df = pd.read_excel('./Control-vs-HSC70.xlsx')
df.head()
# Out:
#   Unnamed: 0     baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# 0          1   266.966616       -0.161203  0.183884 -0.876653  0.380675
# 1        100   172.815340        0.045171  0.232789  0.194041  0.846144
# 2       1000  1528.980886        0.082050  0.112894  0.726788  0.467356
# 3      10000  2440.291233       -0.042886  0.103000 -0.416367  0.677141
# 4      10001   427.143679        0.238312  0.171083  1.392959  0.163632
#
#        padj
# 0  0.985457
# 1  0.997116
# 2  0.985457
# 3  0.987045
# 4  0.985457

# %%
# 调用函数生成火山图
draw_volcano_plot(df, 1, 10)
